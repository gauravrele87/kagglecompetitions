# %%
import random
import numpy as np
import matplotlib.pyplot as plt
random.seed(1)
from matplotlib import *
from matplotlib.animation import FuncAnimation
# %matplotlib inline
plt.rcParams["animation.html"] = "jshtml"

# %%
x = np.random.rand(50)
c = 2.3
m = 1.5

y = m*x + c

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, 1), ylim=(0, 5))
plt.plot(x,y,'.')
line, = ax.plot([], [])
plt.close()

guess_w0 = -1
guess_w1 = -1

def predicted_function(x,w0,w1):
    return w0+x*w1

def init():
    line.set_data(x,y)

def gradient_descent(i,guess_w0,guess_w1,x):
    lr = 0.1
    for _ in range(i):
        dLdw0 = -2*np.sum(y - predicted_function(x,guess_w0,guess_w1))/float(len(x))
        dLdw1 = -2*np.sum((y - predicted_function(x,guess_w0,guess_w1))*x)/float(len(x))
        guess_w0 -= lr* dLdw0
        guess_w1 -= lr* dLdw1
        line.set_data(x, guess_w0 + x*guess_w1)
    return line,

anim = FuncAnimation(fig, gradient_descent, init_func=init,fargs=(guess_w0,guess_w1,x), frames=200,interval=20)
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc58037a66b3645f2a827f04b157e9ab8">
#     <br>
#     <input id="_anim_sliderc58037a66b3645f2a827f04b157e9ab8" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc58037a66b3645f2a827f04b157e9ab8.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc58037a66b3645f2a827f04b157e9ab8.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc58037a66b3645f2a827f04b157e9ab8" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc58037a66b3645f2a827f04b157e9ab8";
#     var slider_id = "_anim_sliderc58037a66b3645f2a827f04b157e9ab8";
#     var loop_select_id = "_anim_loop_selectc58037a66b3645f2a827f04b157e9ab8";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvpW3flQAAFiVJREFUeJzt3XtwlPW9x/HPhgWsggpIFI2CMQ6E\
# xIAkmKAQiVS5NKIoImJVBhHPmHMcUY5Oa6l41NrLqZUjSmcrlVYg1KPTg0WgDkWpWrEmoNNAlXsg\
# DMWA3LwkJNnf+QNIskkgzyq7z36T92vGqdk8T/rtU8zb5x5wzjkBAGBMkt8DAADwTRAwAIBJBAwA\
# YBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwA\
# YBIBAwCYRMAAACYRMACASQQMAGASAQMAmETAAAAmETAAgEkEDABgEgEDAJhEwAAAJhEwAIBJBAwA\
# YBIBAwCYRMAAACYRMACASUG/B/CqT58+6tq1qzp06KBgMKiSkhK/RwIA+MhMwCTprbfe0jnnnOP3\
# GACABMAhRACASWYCFggEdN111yk7O1uhUMjvcQAAPjNzCPG9997T+eefr88++0zXXnut+vXrp/z8\
# /IhlQqFQfdw++eQT9evXz49RAcCs7du3a+/evX6P4UnAOef8HiJas2bNUpcuXTRjxowTLpOTk8OF\
# HgAQJUu/O00cQvzyyy91+PDh+r9/8803lZmZ6fNUAAA/mTiEuGfPHo0bN06SVFtbq0mTJmnUqFE+\
# TwUA8JOJgKWmpurjjz/2ewwAQAIxcQgRAICmCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImA\
# AQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImA\
# AQBMImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImA\
# AQBMImAAAJMIGADAJFMBq6ur0+WXX67CwkK/RwEA+MxUwGbPnq309HS/xwAAJAAzAauoqNAbb7yh\
# qVOn+j0KACABmAnYAw88oJ///OdKSjIzMgAghkzUYOnSpUpOTlZ2dvZJlwuFQsrJyVFOTo4qKyvj\
# NB0AwA8B55zze4jW/OAHP9DLL7+sYDCoqqoqHTp0SDfddJMWLFhwwnVycnJUUlISxykBwD5LvztN\
# 7IE9/fTTqqio0Pbt27V48WJdc801J40XAKDtMxEwAACaCvo9QLSGDx+u4cOH+z0GAMBn7IEBAEwi\
# YAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIGAAlu0Qc7dMeLa7Togx1+j5JQzN3IDABtmnPS\
# e7OllY/VfzTp2F99Ni86+nXuRf7MlmAIGAD4pa5GenOm9MHcVhddUDtCkrS8bDcBO4aAAUAMlZbv\
# 15qt+3TlhZ11eekPpX++7m3FbhdL339NizZ31A//+I/6j0dn9orRpPYQMAA41fZtkZ4bJEnKPvbX\
# SfUeKt3yktQludm3JvU4+p/Ly3ZrdGYv9r4aIWAA8G3sWCP9dqT35TNuksY+J3Xu4nmVSbkXEa4W\
# EDAA8GjnG7/QhR8+6Xn5r7r1U+7eR/VVbQd1DCZp4dQ8ZffuFsMJ2xcCBgAt+b8i6aPIF+deeLLl\
# 06+Xbvm9lNRwd9LpkuYfOweWl9qDeJ1iBAxA++ac9Oth0p5/tL7sMXNrxyo84jEVFaS1umx2726E\
# K0YIGID2o65GeuKc6NYZOl367iyVlu/X7S+uUU1t+OjhwNQeMRkR3hEwAG1Oafl+rft0m6b+rSC6\
# FW+cKw2c1OK3snt308KpeRwOTCAEDIBZiz7YoeVluzWx9xf63rs31X/u6dL1ycukPldF9d/H4cDE\
# QsAAmFFavl9fvDNXV2/+maSGRyxpZysr/sdaqcclMZ4O8UbAACSM0qZX7L12j/SPV
